# %% [markdown]
# #### Columns to be created:
#     - Name,ratings,reviews,company_type,head_quarters,old,employees

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page=1"

# %%
requests.get(url)
# Out:
# <Response [403]>

# %%
requests.get(url).text
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;list&#45;of&#45;companies&#63;" on this server.<P>\nReference&#32;&#35;18&#46;162a336a&#46;1704977059&#46;5157a2d\n</BODY>\n</HTML>\n'

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get(url,headers=headers).text

# %%
# webpage

# %%
soup = BeautifulSoup(webpage)
#soup.prettify

# %%
soup.find('h1').text.strip()
# Out:
# 'List of companies in India'

# %% [markdown]
# ## Name of the company

# %%
soup.find_all('h2',class_='companyCardWrapper__companyName')
# Out:
# [<h2 class="companyCardWrapper__companyName" title="TCS">
#  										TCS
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Accenture">
#  										Accenture
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Cognizant">
#  										Cognizant
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Wipro">
#  										Wipro
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="HDFC Bank">
#  										HDFC Bank
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="ICICI Bank">
#  										ICICI Bank
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Infosys">
#  										Infosys
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Capgemini">
#  										Capgemini
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="HCLTech">
#  										HCLTech
#  									</h2>,
# ...

# %%
len(soup.find_all('h2',class_ = 'companyCardWrapper__companyName'))
# Out:
# 20

# %%
Name = []

for i in soup.find_all('h2',class_='companyCardWrapper__companyName'):
    #print(i.text.strip())
    Name.append(i.text.strip())
    
Name
# Out:
# ['TCS',
#  'Accenture',
#  'Cognizant',
#  'Wipro',
#  'HDFC Bank',
#  'ICICI Bank',
#  'Infosys',
#  'Capgemini',
#  'HCLTech',
#  'Tech Mahindra',
#  'Genpact',
#  'Axis Bank',
#  'Concentrix Corporation',
#  'Teleperformance',
#  'Amazon',
#  'Reliance Jio',
#  'IBM',
#  'Larsen & Toubro Limited',
#  'Reliance Retail',
#  'HDB Financial Services']

# %% [markdown]
# ## Rating

# %%
soup.find_all('span',class_ = 'companyCardWrapper__companyRatingValue')
# Out:
# [<span class="companyCardWrapper__companyRatingValue">3.8</span>,
#  <span class="companyCardWrapper__companyRatingValue">4.0</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.9</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.8</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.9</span>,
#  <span class="companyCardWrapper__companyRatingValue">4.0</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.8</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.8</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.6</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.7</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.9</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.8</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.9</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.5</span>,
# ...

# %%
len(soup('span', class_='companyCardWrapper__companyRatingValue'))
# Out:
# 20

# %%
Rating = []

for i in soup.find_all('span',class_ = 'companyCardWrapper__companyRatingValue'):
    #print(i.text.strip())
    Rating.append(i.text.strip())
    
Rating
# Out:
# ['3.8',
#  '4.0',
#  '3.9',
#  '3.8',
#  '3.9',
#  '4.0',
#  '3.8',
#  '3.8',
#  '3.6',
#  '3.7',
#  '3.9',
#  '3.8',
#  '3.9',
#  '3.5',
#  '4.1',
#  '4.0',
#  '4.1',
#  '4.0',
#  '3.9',
#  '4.0']

# %% [markdown]
# ## Number of employees

# %%
soup.find_all('span',class_ = 'companyCardWrapper__interLinking')
# Out:
# [<span class="companyCardWrapper__interLinking">
#  									IT Services &amp; Consulting | 1 Lakh+ Employees | Public | 56 years old | Mumbai +335 more
#  								</span>,
#  <span class="companyCardWrapper__interLinking">
#  									IT Services &amp; Consulting | 1 Lakh+ Employees | Public | 35 years old | Dublin +166 more
#  								</span>,
#  <span class="companyCardWrapper__interLinking">
#  									IT Services &amp; Consulting | 1 Lakh+ Employees | Forbes Global 2000 | 30 years old | Teaneck. New Jersey. +153 more
#  								</span>,
#  <span class="companyCardWrapper__interLinking">
#  									IT Services &amp; Consulting | 1 Lakh+ Employees | Public | 79 years old | Bangalore/Bengaluru +268 more
#  								</span>,
#  <span class="companyCardWrapper__interLinking">
#  									Banking | 1 Lakh+ Employees | Public | 30 years old | Mumbai +1513 more
#  								</span>,
#  <span class="companyCardWrapper__interLinking">
# ...

# %%
len(soup.find_all('span',class_ = 'companyCardWrapper__interLinking'))
# Out:
# 20

# %%
Number_of_employees = []

for i in soup.find_all('span',class_ = 'companyCardWrapper__interLinking'):
    #print(i.text.strip().split('|')[1].strip())
    Number_of_employees.append(i.text.strip().split('|')[1].strip())
    
Number_of_employees
# Out:
# ['1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '50k-1 Lakh Employees',
#  '50k-1 Lakh Employees',
#  '50k-1 Lakh Employees',
#  '1 Lakh+ Employees',
#  '50k-1 Lakh Employees',
#  '1 Lakh+ Employees',
#  '10k-50k Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees']

# %% [markdown]
# ## Type of company

# %%
company_type = []

for i in soup.find_all('span',class_ = 'companyCardWrapper__interLinking'):
    #print(i.text.strip().split('|')[2].strip())
    company_type.append(i.text.strip().split('|')[2].strip())
    
company_type
# Out:
# ['Public',
#  'Public',
#  'Forbes Global 2000',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Forbes Global 2000',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  '18 years old',
#  '17 years old']

# %% [markdown]
# ## Headquarters

# %%
hq = []

for i in soup.find_all('span',class_ = 'companyCardWrapper__interLinking'):
    #print(i.text.strip().split('|')[-1].split()[0])
    hq.append(i.text.strip().split('|')[-1].split()[0])
    
hq
# Out:
# ['Mumbai',
#  'Dublin',
#  'Teaneck.',
#  'Bangalore/Bengaluru',
#  'Mumbai',
#  'Mumbai',
#  'Bengaluru/Bangalore',
#  'Paris',
#  'Noida',
#  'Pune',
#  'New',
#  'Mumbai',
#  'Fremont',
#  'Paris',
#  'Seattle',
#  'Navi',
#  'Armonk',
#  'Mumbai',
#  'Navi',
#  'Ahmedabad']

# %% [markdown]
# ## How old is the company

# %%
old = []

for i in soup.find_all('span',class_ = 'companyCardWrapper__interLinking'):
    #print(i.text.strip().split('|')[-2].split()[0])
    old.append(i.text.strip().split('|')[-2].split()[0])
    
old
# Out:
# ['56',
#  '35',
#  '30',
#  '79',
#  '30',
#  '30',
#  '43',
#  '57',
#  '33',
#  '38',
#  '27',
#  '31',
#  '41',
#  '46',
#  '30',
#  '17',
#  '113',
#  '86',
#  '18',
#  '17']

# %% [markdown]
# ## Number of reviews

# %%
Reviews = []

for i in soup.find_all('span',class_ = 'companyCardWrapper__ActionCount')[::6]:
    #print(i.text.strip())
    Reviews.append(i.text.strip())
    
Reviews
# Out:
# ['71.8k',
#  '45.5k',
#  '41k',
#  '36.3k',
#  '33.3k',
#  '33k',
#  '31.2k',
#  '29.1k',
#  '27.9k',
#  '27k',
#  '25.7k',
#  '21.6k',
#  '21.4k',
#  '20.4k',
#  '20.4k',
#  '20.3k',
#  '19.4k',
#  '18.4k',
#  '18.4k',
#  '17.8k']

# %% [markdown]
# ## Creating a dictionary

# %%
d = {'Name':Name,'Rating':Rating,'Reviews':Reviews,'Company_Type':company_type,'hq':hq,'Old':old,'Employees':Number_of_employees}

# %%
df = pd.DataFrame(d)
df
# Out:
#                        Name Rating Reviews        Company_Type  \
# 0                       TCS    3.8   71.8k              Public
# 1                 Accenture    4.0   45.5k              Public
# 2                 Cognizant    3.9     41k  Forbes Global 2000
# 3                     Wipro    3.8   36.3k              Public
# 4                 HDFC Bank    3.9   33.3k              Public
# 5                ICICI Bank    4.0     33k              Public
# 6                   Infosys    3.8   31.2k              Public
# 7                 Capgemini    3.8   29.1k              Public
# 8                   HCLTech    3.6   27.9k              Public
# 9             Tech Mahindra    3.7     27k              Public
# 10                  Genpact    3.9   25.7k              Public
# 11                Axis Bank    3.8   21.6k              Public
# 12   Concentrix Corporation    3.9   21.4k              Public
# 13          Teleperformance    3.5   20.4k  Forbes Global 2000
# ...

# %% [markdown]
# # Considering the whole container

# %%
name = []
rating = []
reviews = []
ctype = []
hq = []
old = []
employees = []

# %%
len(soup.find_all('div',class_ = 'companyCardWrapper'))
# Out:
# 20

# %%
for i in soup.find_all('div',class_ = 'companyCardWrapper'):
    name.append(i.find('h2').text.strip())
    rating.append(i.find('span',class_ = 'companyCardWrapper__companyRatingValue').text.strip())
    reviews.append(i.find('span',class_ = 'companyCardWrapper__ActionCount').text.strip())
    ctype.append(i.find('span',class_ = 'companyCardWrapper__interLinking').text.strip().split('|')[2].strip())
    hq.append(i.find('span',class_ = 'companyCardWrapper__interLinking').text.strip().split('|')[-1].strip().split()[0].strip())
    old.append(i.find('span',class_ = 'companyCardWrapper__interLinking').text.strip().split('|')[-2].strip().split()[0].strip())
    employees.append(i.find('span',class_ = 'companyCardWrapper__interLinking').text.strip().split('|')[1].strip())

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'Cognizant',
#  'Wipro',
#  'HDFC Bank',
#  'ICICI Bank',
#  'Infosys',
#  'Capgemini',
#  'HCLTech',
#  'Tech Mahindra',
#  'Genpact',
#  'Axis Bank',
#  'Concentrix Corporation',
#  'Teleperformance',
#  'Amazon',
#  'Reliance Jio',
#  'IBM',
#  'Larsen & Toubro Limited',
#  'Reliance Retail',
#  'HDB Financial Services']

# %%
rating
# Out:
# ['3.8',
#  '4.0',
#  '3.9',
#  '3.8',
#  '3.9',
#  '4.0',
#  '3.8',
#  '3.8',
#  '3.6',
#  '3.7',
#  '3.9',
#  '3.8',
#  '3.9',
#  '3.5',
#  '4.1',
#  '4.0',
#  '4.1',
#  '4.0',
#  '3.9',
#  '4.0']

# %%
reviews
# Out:
# ['71.8k',
#  '45.5k',
#  '41k',
#  '36.3k',
#  '33.3k',
#  '33k',
#  '31.2k',
#  '29.1k',
#  '27.9k',
#  '27k',
#  '25.7k',
#  '21.6k',
#  '21.4k',
#  '20.4k',
#  '20.4k',
#  '20.3k',
#  '19.4k',
#  '18.4k',
#  '18.4k',
#  '17.8k']

# %%
ctype
# Out:
# ['Public',
#  'Public',
#  'Forbes Global 2000',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Forbes Global 2000',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  '18 years old',
#  '17 years old']

# %%
hq
# Out:
# ['Mumbai',
#  'Dublin',
#  'Teaneck.',
#  'Bangalore/Bengaluru',
#  'Mumbai',
#  'Mumbai',
#  'Bengaluru/Bangalore',
#  'Paris',
#  'Noida',
#  'Pune',
#  'New',
#  'Mumbai',
#  'Fremont',
#  'Paris',
#  'Seattle',
#  'Navi',
#  'Armonk',
#  'Mumbai',
#  'Navi',
#  'Ahmedabad']

# %%
old
# Out:
# ['56',
#  '35',
#  '30',
#  '79',
#  '30',
#  '30',
#  '43',
#  '57',
#  '33',
#  '38',
#  '27',
#  '31',
#  '41',
#  '46',
#  '30',
#  '17',
#  '113',
#  '86',
#  '18',
#  '17']

# %%
employees
# Out:
# ['1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees',
#  '50k-1 Lakh Employees',
#  '50k-1 Lakh Employees',
#  '50k-1 Lakh Employees',
#  '1 Lakh+ Employees',
#  '50k-1 Lakh Employees',
#  '1 Lakh+ Employees',
#  '10k-50k Employees',
#  '1 Lakh+ Employees',
#  '1 Lakh+ Employees']

# %%
df = pd.DataFrame({'Name':name,'Ratings':rating,'Reviews':reviews,'Company_Type':ctype,'HQ':hq,'Old':old,'Number_of_employees':employees})

df
# Out:
#                        Name Ratings Reviews        Company_Type  \
# 0                       TCS     3.8   71.8k              Public
# 1                 Accenture     4.0   45.5k              Public
# 2                 Cognizant     3.9     41k  Forbes Global 2000
# 3                     Wipro     3.8   36.3k              Public
# 4                 HDFC Bank     3.9   33.3k              Public
# 5                ICICI Bank     4.0     33k              Public
# 6                   Infosys     3.8   31.2k              Public
# 7                 Capgemini     3.8   29.1k              Public
# 8                   HCLTech     3.6   27.9k              Public
# 9             Tech Mahindra     3.7     27k              Public
# 10                  Genpact     3.9   25.7k              Public
# 11                Axis Bank     3.8   21.6k              Public
# 12   Concentrix Corporation     3.9   21.4k              Public
# 13          Teleperformance     3.5   20.4k  Forbes Global 2000
# ...

# %% [markdown]
# # Creating dataframe for all pages

# %%
final = pd.DataFrame()

for x in range(0,351):
    url = 'https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page={}'.format(x)
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage = requests.get(url,headers=headers).text
    soup = BeautifulSoup(webpage)
    company = soup.find_all('div', class_ = 'companyCardWrapper')
    
    name = []
    rating = []
    reviews = []
    industry = []
    hq = []
    employees = []
    
    for i in company:
        try:
            name.append(i.find('h2').text.strip())
        except:
            name.append(np.nan)
            
        try:
            rating.append(i.find('span',class_ = 'companyCardWrapper__companyRatingValue').text.strip())
        except:
            rating.append(np.nan)
            
        try:
            reviews.append(i.find('span',class_ = 'companyCardWrapper__ActionCount').text.strip())
        except:
            reviews.append(np.nan)
        
        try:
            industry.append(i.find('span',class_ = 'companyCardWrapper__interLinking').text.strip().split('|')[0].strip())
        except:
            industry.append(np.nan)
        
        try:
            hq.append(i.find('span',class_ = 'companyCardWrapper__interLinking').text.strip().split('|')[-1].strip())
        except:
            hq.append(np.nan)
        
        try:
            employees.append(i.find('span',class_ = 'companyCardWrapper__interLinking').text.strip().split('|')[1].strip())
        except:
            employees.append(np.nan)
            
    df = pd.DataFrame({'Name':name,
                       'Ratings':rating,
                       'Reviews':reviews,
                       'Industry':industry,
                       'HQ':hq,
                       'Number_of_employees':employees})

    final = final.append(df,ignore_index=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12736\1093622035.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df,ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12736\1093622035.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df,ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12736\1093622035.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df,ignore_index=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12736\1093622035.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df,ignore_index=True)
# ...

# %%
df
# Out:
#                                                  Name Ratings Reviews  \
# 0                                         CI Infotech     3.6     103
# 1                                    KRG Technologies     3.9     103
# 2                                       Minda Kyoraku     3.9     103
# 3                                       M K Agro Tech     3.4     103
# 4   PKF Sridhar & Santhanam LLP, Chartered Account...     3.6     103
# 5                          IJM (India) Infrastructure     4.0     103
# 6                                       TFG Vacations     4.3     103
# 7                       Kamlesh Kumar Singh Engineers     4.3     103
# 8                                          Cyient DLM     3.7     103
# 9                               Sushee Infra & Mining     4.2     103
# 10                                      Veoneer India     3.9     103
# 11               Ebix Smartclass Educational Services     3.4     103
# ...

# %%
df.shape
# Out:
# (20, 6)

# %%
final.shape
# Out:
# (7000, 6)

# %%
final.tail()
# Out:
#                                      Name Ratings Reviews  \
# 6995                       Mantra Softech     3.9     103
# 6996                       QUTONE CERAMIC     3.8     103
# 6997                     Raheja Universal     4.0     103
# 6998                NIFTEL COMMUNICATIONS     3.7     103
# 6999  Milltec Machinery Pvt Ltd Bangalore     3.7     103
#
#                       Industry                  HQ Number_of_employees
# 6995  IT Services & Consulting  Ahmedabad +13 more    51-200 Employees
# 6996         Building Material  Ahmedabad +21 more    51-200 Employees
# 6997               Real Estate      Mumbai +6 more    501-1k Employees
# 6998                       BPO     Lucknow +6 more   201-500 Employees
# 6999      Industrial Machinery  Bangalore +14 more    501-1k Employees

# %%
final.loc[final['Name'] == 'Cognizant']
# Out:
#         Name Ratings Reviews                  Industry  \
# 2  Cognizant     3.9     41k  IT Services & Consulting
#
#                                HQ Number_of_employees
# 2  Teaneck. New Jersey. +153 more   1 Lakh+ Employees

# %%
final.to_csv('ambitionbox.csv')

# %%
final.describe()
# Out:
#                      Name Ratings Reviews                  Industry  \
# count                7000    7000    7000                      7000
# unique               6745      32     854                       178
# top     Connect Broadband     4.0     112  IT Services & Consulting
# freq                    2     866      80                       879
#
#                      HQ Number_of_employees
# count              7000                6927
# unique             3591                 149
# top     Mumbai +12 more     1k-5k Employees
# freq                 38                2291

# %%
final
# Out:
#                                      Name Ratings Reviews  \
# 0                                     TCS     3.8   71.8k
# 1                               Accenture     4.0   45.5k
# 2                               Cognizant     3.9     41k
# 3                                   Wipro     3.8   36.3k
# 4                               HDFC Bank     3.9   33.3k
# ...                                   ...     ...     ...
# 6995                       Mantra Softech     3.9     103
# 6996                       QUTONE CERAMIC     3.8     103
# 6997                     Raheja Universal     4.0     103
# 6998                NIFTEL COMMUNICATIONS     3.7     103
# 6999  Milltec Machinery Pvt Ltd Bangalore     3.7     103
#
#                       Industry                              HQ  \
# 0     IT Services & Consulting                Mumbai +335 more
# 1     IT Services & Consulting                Dublin +166 more
# 2     IT Services & Consulting  Teaneck. New Jersey. +153 more
# ...

# %%
final.head(100)
# Out:
#                 Name Ratings Reviews                           Industry  \
# 0                TCS     3.8   71.8k           IT Services & Consulting
# 1          Accenture     4.0   45.5k           IT Services & Consulting
# 2          Cognizant     3.9     41k           IT Services & Consulting
# 3              Wipro     3.8   36.3k           IT Services & Consulting
# 4          HDFC Bank     3.9   33.3k                            Banking
# ..               ...     ...     ...                                ...
# 95     Ashok Leyland     4.1    4.2k                         Automobile
# 96  Apollo Hospitals     4.1    4.2k                         Healthcare
# 97           Siemens     4.2    4.1k                              Power
# 98               JLL     4.2    4.1k                        Real Estate
# 99              Vivo     4.1    4.1k  Consumer Electronics & Appliances
#
#                                 HQ Number_of_employees
# ...
